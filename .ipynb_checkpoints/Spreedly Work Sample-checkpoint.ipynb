# %% [markdown]
# # Michael Bostwick
# ### Data Science Internship Work Sample
#
# ### Q1.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('intern2017.csv', header = 0)

# %%
#df.head(5)

# %%
df.status.unique()
# Out:
# array(['gateway_processing_failed', 'succeeded', 'failed',
#        'gateway_processing_result_unknown'], dtype=object)

# %%
df['success'] = (df.status == 'succeeded')

# %% [markdown]
# ### A.

# %%
df.groupby(['gateway', 'transaction_type'])['success'].mean()
# Out:
# gateway  transaction_type
# GA       Authorization       0.125828
#          Credit              0.642857
#          Purchase            0.650854
# GB       Authorization       0.361089
#          Credit              0.423077
#          Purchase            0.371340
# Name: success, dtype: float64

# %%
df['date'] = pd.to_datetime(df.epoch_date, unit='s')
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['month_year'] = (df.year - 2014)*12 + df.month
df_a = df[(df['gateway'] == 'GA') & (df['transaction_type'] == 'Purchase') & (df['year'] > 2013)]
df_a = df_a[['success', 'month_year', 'gateway']]
df_b = df[(df['gateway'] == 'GB') & (df['transaction_type'] == 'Purchase') & (df['year'] > 2013)]
df_b = df_b[['success', 'month_year', 'gateway']]

# %% [markdown]
# ### B.

# %%
table_a = df_a.groupby(['month_year'])['success'].mean()
table_b = df_b.groupby(['month_year'])['success'].mean()
table_a.plot(label = 'GA')
table_b.plot(label = 'GB')
plt.legend(loc='lower left', fancybox=True)

x = np.array([0,6,12,18,24, 30])
my_xticks = ['Jan14','July14','Jan15','July15', 'Jan16', 'July16']
plt.xticks(x, my_xticks)
plt.xlabel('Date')
plt.ylabel('Success Rate')
plt.title('GA vs. GB success rates for purchases 2014 - 2016')
plt.show()

# %% [markdown]
# ### Q2.
#
# I have knowledge of a variety of machine learning algorithms, both supervised and unsupervised, as well as exposure to considerations like overfitting, curse of dimensionality and feature representation and engineering. Some specific algorithms that I am familiar with include random forests, k-Nearest Neighbor, Principal Component Analysis and Naive Bayes. This semester I am in an advanced machine learning course where I am gaining a stronger foundation in optimization, Bayesian approaches and different types of inference.
#
# A machine learning project that I worked on last semester for a text mining course was to predict new restaurant ratings from previous user review text on Yelp. In order to create features from the text I used Latent Dirichlet Allocation to find topic distributions for each review and then created aggregated user level topic distributions for both their positive and negative reviews. These topic distributions were then used as features in a k-Nearest neighbor algorithm to find similar users and predict their weighted average rating at the new restaurant.
